# %%
import sympy as sp

# %%
t, x = sp.symbols('t x')

# %%
rho = sp.Function('rho')(t, x)

# %%
rho_str_list = [f'drho_x[{n}]' for n in range(6)]
q_str_list = [f'dq_x[{n}]' for n in range(6)]
E_str_list = [f'dE_x[{n}]' for n in range(6)]
rho_symbols_string_list = ['R', 'R_x', 'R_xx', 'R_xxx', 'R_xxxx', 'R_xxxxx']
q_symbols_string_list = ['Q', 'Q_x', 'Q_xx', 'Q_xxx', 'Q_xxxx', 'Q_xxxxx']
E_symbols_string_list = ['U', 'U_x', 'U_xx', 'U_xxx', 'U_xxxx', 'U_xxxxx']
rho_string_replacement_list = list(zip(rho_symbols_string_list, rho_str_list))
q_string_replacement_list = list(zip(q_symbols_string_list, q_str_list))
E_string_replacement_list = list(zip(E_symbols_string_list, E_str_list))

# %%
R, rho_x, rho_xx, rho_xxx, rho_xxxx, rho_xxxxx = sp.symbols('R, R_x, R_xx, R_xxx, R_xxxx, R_xxxxx')

# %%
rho_symbols_list = [R, rho_x, rho_xx, rho_xxx, rho_xxxx, rho_xxxxx]

# %%
rho_derivative_list = [sp.diff(rho, x, k) for k in range(6)]

# %%
rho_sub_list = list(zip(rho_derivative_list, rho_symbols_list))

# %%
rho_sub_list = rho_sub_list[::-1]

# %%
rho_sub_list
# Out:
# [(Derivative(rho(t, x), (x, 5)), R_xxxxx),
#  (Derivative(rho(t, x), (x, 4)), R_xxxx),
#  (Derivative(rho(t, x), (x, 3)), R_xxx),
#  (Derivative(rho(t, x), (x, 2)), R_xx),
#  (Derivative(rho(t, x), x), R_x),
#  (rho(t, x), R)]

# %%
q = sp.Function('q')(t, x)

# %%
Q, q_x, q_xx, q_xxx, q_xxxx, q_xxxxx = sp.symbols('Q, Q_x, Q_xx, Q_xxx, Q_xxxx, Q_xxxxx')

# %%
q_symbols_list = [Q, q_x, q_xx, q_xxx, q_xxxx, q_xxxxx]

# %%
q_derivative_list = [sp.diff(q, x, k) for k in range(6)]

# %%
q_sub_list = list(zip(q_derivative_list, q_symbols_list))

# %%
q_sub_list = q_sub_list[::-1]

# %%
E = sp.Function('E')(t, x)

# %%
U, E_x, E_xx, E_xxx, E_xxxx, E_xxxxx = sp.symbols('U, U_x, U_xx, U_xxx, U_xxxx, U_xxxxx')

# %%
E_symbols_list = [U, E_x, E_xx, E_xxx, E_xxxx, E_xxxxx]

# %%
E_derivative_list = [sp.diff(E, x, k) for k in range(6)]

# %%
E_sub_list = list(zip(E_derivative_list, E_symbols_list))

# %%
E_sub_list = E_sub_list[::-1]

# %%
gamma = sp.symbols('gamma')

# %%
p = (gamma - 1) * (E - 0.5 * q ** 2 / rho)

# %%
u = q / rho

# %%
rho_t = -sp.diff(q, x)

# %%
rho_t
# Out:
# -Derivative(q(t, x), x)

# %%
q_t = -sp.diff(rho * u ** 2 + p, x)

# %%
q_t
# Out:
# -(gamma - 1)*(0.5*q(t, x)**2*Derivative(rho(t, x), x)/rho(t, x)**2 - 1.0*q(t, x)*Derivative(q(t, x), x)/rho(t, x) + Derivative(E(t, x), x)) + q(t, x)**2*Derivative(rho(t, x), x)/rho(t, x)**2 - 2*q(t, x)*Derivative(q(t, x), x)/rho(t, x)

# %%
E_t = -sp.diff((E + p) * u, x)

# %%
E_t
# Out:
# ((gamma - 1)*(E(t, x) - 0.5*q(t, x)**2/rho(t, x)) + E(t, x))*q(t, x)*Derivative(rho(t, x), x)/rho(t, x)**2 - ((gamma - 1)*(E(t, x) - 0.5*q(t, x)**2/rho(t, x)) + E(t, x))*Derivative(q(t, x), x)/rho(t, x) - ((gamma - 1)*(0.5*q(t, x)**2*Derivative(rho(t, x), x)/rho(t, x)**2 - 1.0*q(t, x)*Derivative(q(t, x), x)/rho(t, x) + Derivative(E(t, x), x)) + Derivative(E(t, x), x))*q(t, x)/rho(t, x)

# %%
rho_ck = [rho, rho_t]
q_ck = [q, q_t]
E_ck = [E, E_t]

# %%
for i in range(2, 6):
    next_rho_der = sp.simplify(sp.diff(rho_ck[-1], t).subs(((sp.diff(rho, t), rho_t), (sp.diff(q, t), q_t), (sp.diff(E, t), E_t)), simultaneous=True))
    next_q_der = sp.simplify(sp.diff(q_ck[-1], t).subs(((sp.diff(rho, t), rho_t), (sp.diff(q, t), q_t), (sp.diff(E, t), E_t)), simultaneous=True))
    next_E_der = sp.simplify(sp.diff(E_ck[-1], t).subs(((sp.diff(rho, t), rho_t), (sp.diff(q, t), q_t), (sp.diff(E, t), E_t)), simultaneous=True))
    rho_ck.append(next_rho_der)
    q_ck.append(next_q_der)
    E_ck.append(next_E_der)

# %%
expr = sp.expand(E_ck[5])

# %%
expr = sp.nsimplify(expr)

# %%
expr = expr.subs(rho_sub_list).subs(q_sub_list).subs(E_sub_list)

# %%
sp.ccode(expr)
# Out:
# '-1.0/4.0*pow(Q, 7)*R_xxxxx*pow(gamma, 5)/pow(R, 7) + (11.0/8.0)*pow(Q, 7)*R_xxxxx*pow(gamma, 4)/pow(R, 7) + (29.0/8.0)*pow(Q, 7)*R_xxxxx*pow(gamma, 3)/pow(R, 7) - 103.0/8.0*pow(Q, 7)*R_xxxxx*pow(gamma, 2)/pow(R, 7) + (5.0/8.0)*pow(Q, 7)*R_xxxxx*gamma/pow(R, 7) + (15.0/2.0)*pow(Q, 7)*R_xxxxx/pow(R, 7) + (43.0/8.0)*pow(Q, 7)*R_x*R_xxxx*pow(gamma, 5)/pow(R, 8) - 75.0/2.0*pow(Q, 7)*R_x*R_xxxx*pow(gamma, 4)/pow(R, 8) - 213.0/2.0*pow(Q, 7)*R_x*R_xxxx*pow(gamma, 3)/pow(R, 8) + (1451.0/4.0)*pow(Q, 7)*R_x*R_xxxx*pow(gamma, 2)/pow(R, 8) + (457.0/8.0)*pow(Q, 7)*R_x*R_xxxx*gamma/pow(R, 8) - 1125.0/4.0*pow(Q, 7)*R_x*R_xxxx/pow(R, 8) + (85.0/8.0)*pow(Q, 7)*R_xx*R_xxx*pow(gamma, 5)/pow(R, 8) - 645.0/8.0*pow(Q, 7)*R_xx*R_xxx*pow(gamma, 4)/pow(R, 8) - 1335.0/8.0*pow(Q, 7)*R_xx*R_xxx*pow(gamma, 3)/pow(R, 8) + (4975.0/8.0)*pow(Q, 7)*R_xx*R_xxx*pow(gamma, 2)/pow(R, 8) + (785.0/4.0)*pow(Q, 7)*R_xx*R_xxx*gamma/pow(R, 8) - 2325.0/4.0*pow(Q, 7)*R_xx*R_xxx/pow(R, 8) - 453.0/8.0*pow(Q, 7)*pow(R_x, 2)*R_xxx*pow(gamma, 5)/pow(R, 9) + (4173.0/8.0)*pow(Q, 7)*pow(R_x, 2)*R_xxx*pow(gamma, 4)/pow(R, 9) + (10683.0/8.0)*pow(Q, 7)*pow(R_x, 2)*R_xxx*pow(gamma, 3)/pow(R, 9) - 36623.0/8.0*pow(Q, 7)*pow(R_x, 2)*R_xxx*pow(gamma, 2)/pow(R, 9) - 7835.0/4.0*pow(Q, 7)*pow(R_x, 2)*R_xxx*gamma/pow(R, 9) + (18945.0/4.0)*pow(Q, 7)*pow(R_x, 2)*R_xxx/pow(R, 9) - 333.0/4.0*pow(Q, 7)*R_x*pow(R_xx, 2)*pow(gamma, 5)/pow(R, 9) + (3233.0/4.0)*pow(Q, 7)*R_x*pow(R_xx, 2)*pow(gamma, 4)/pow(R, 9) + (6863.0/4.0)*pow(Q, 7)*R_x*pow(R_xx, 2)*pow(gamma, 3)/pow(R, 9) - 24763.0/4.0*pow(Q, 7)*R_x*pow(R_xx, 2)*pow(gamma, 2)/pow(R, 9) - 6945.0/2.0*pow(Q, 7)*R_x*pow(R_xx, 2)*gamma/pow(R, 9) + (14445.0/2.0)*pow(Q, 7)*R_x*pow(R_xx, 2)/pow(R, 9) + (2749.0/8.0)*pow(Q, 7)*pow(R_x, 3)*R_xx*pow(gamma, 5)/pow(R, 10) - 33685.0/8.0*pow(Q, 7)*pow(R_x, 3)*R_xx*pow(gamma, 4)/pow(R, 10) - 76411.0/8.0*pow(Q, 7)*pow(R_x, 3)*R_xx*pow(gamma, 3)/pow(R, 10) + (264655.0/8.0)*pow(Q, 7)*pow(R_x, 3)*R_xx*pow(gamma, 2)/pow(R, 10) + (97791.0/4.0)*pow(Q, 7)*pow(R_x, 3)*R_xx*gamma/pow(R, 10) - 176445.0/4.0*pow(Q, 7)*pow(R_x, 3)*R_xx/pow(R, 10) - 475.0/2.0*pow(Q, 7)*pow(R_x, 5)*pow(gamma, 5)/pow(R, 11) + (7615.0/2.0)*pow(Q, 7)*pow(R_x, 5)*pow(gamma, 4)/pow(R, 11) + 8435*pow(Q, 7)*pow(R_x, 5)*pow(gamma, 3)/pow(R, 11) - 28775*pow(Q, 7)*pow(R_x, 5)*pow(gamma, 2)/pow(R, 11) - 56235.0/2.0*pow(Q, 7)*pow(R_x, 5)*gamma/pow(R, 11) + (89775.0/2.0)*pow(Q, 7)*pow(R_x, 5)/pow(R, 11) - 11.0/2.0*pow(Q, 6)*Q_x*R_xxxx*pow(gamma, 5)/pow(R, 7) + (243.0/8.0)*pow(Q, 6)*Q_x*R_xxxx*pow(gamma, 4)/pow(R, 7) + (1099.0/8.0)*pow(Q, 6)*Q_x*R_xxxx*pow(gamma, 3)/pow(R, 7) - 2931.0/8.0*pow(Q, 6)*Q_x*R_xxxx*pow(gamma, 2)/pow(R, 7) - 947.0/8.0*pow(Q, 6)*Q_x*R_xxxx*gamma/pow(R, 7) + (645.0/2.0)*pow(Q, 6)*Q_x*R_xxxx/pow(R, 7) + (817.0/8.0)*pow(Q, 6)*Q_x*R_x*R_xxx*pow(gamma, 5)/pow(R, 8) - 6171.0/8.0*pow(Q, 6)*Q_x*R_x*R_xxx*pow(gamma, 4)/pow(R, 8) - 23539.0/8.0*pow(Q, 6)*Q_x*R_x*R_xxx*pow(gamma, 3)/pow(R, 8) + (61933.0/8.0)*pow(Q, 6)*Q_x*R_x*R_xxx*pow(gamma, 2)/pow(R, 8) + (21355.0/4.0)*pow(Q, 6)*Q_x*R_x*R_xxx*gamma/pow(R, 8) - 37875.0/4.0*pow(Q, 6)*Q_x*R_x*R_xxx/pow(R, 8) + 75*pow(Q, 6)*Q_x*pow(R_xx, 2)*pow(gamma, 5)/pow(R, 8) - 4925.0/8.0*pow(Q, 6)*Q_x*pow(R_xx, 2)*pow(gamma, 4)/pow(R, 8) - 15125.0/8.0*pow(Q, 6)*Q_x*pow(R_xx, 2)*pow(gamma, 3)/pow(R, 8) + (40975.0/8.0)*pow(Q, 6)*Q_x*pow(R_xx, 2)*pow(gamma, 2)/pow(R, 8) + (36165.0/8.0)*pow(Q, 6)*Q_x*pow(R_xx, 2)*gamma/pow(R, 8) - 28845.0/4.0*pow(Q, 6)*Q_x*pow(R_xx, 2)/pow(R, 8) - 6699.0/8.0*pow(Q, 6)*Q_x*pow(R_x, 2)*R_xx*pow(gamma, 5)/pow(R, 9) + (69027.0/8.0)*pow(Q, 6)*Q_x*pow(R_x, 2)*R_xx*pow(gamma, 4)/pow(R, 9) + (218805.0/8.0)*pow(Q, 6)*Q_x*pow(R_x, 2)*R_xx*pow(gamma, 3)/pow(R, 9) - 566547.0/8.0*pow(Q, 6)*Q_x*pow(R_x, 2)*R_xx*pow(gamma, 2)/pow(R, 9) - 326463.0/4.0*pow(Q, 6)*Q_x*pow(R_x, 2)*R_xx*gamma/pow(R, 9) + (234585.0/2.0)*pow(Q, 6)*Q_x*pow(R_x, 2)*R_xx/pow(R, 9) + (3545.0/4.0)*pow(Q, 6)*Q_x*pow(R_x, 4)*pow(gamma, 5)/pow(R, 10) - 47741.0/4.0*pow(Q, 6)*Q_x*pow(R_x, 4)*pow(gamma, 4)/pow(R, 10) - 70741.0/2 ...

# %%
string = sp.ccode(expr)

# %%
for replacement in rho_string_replacement_list[::-1]:
    string: str = string.replace(replacement[0], replacement[1])

# %%
for replacement in q_string_replacement_list[::-1]:
    string: str = string.replace(replacement[0], replacement[1])

# %%
for replacement in E_string_replacement_list[::-1]:
    string: str = string.replace(replacement[0], replacement[1])

# %%
print(string)
# Out:
# -1.0/4.0*pow(dq_x[0], 7)*drho_x[5]*pow(gamma, 5)/pow(drho_x[0], 7) + (11.0/8.0)*pow(dq_x[0], 7)*drho_x[5]*pow(gamma, 4)/pow(drho_x[0], 7) + (29.0/8.0)*pow(dq_x[0], 7)*drho_x[5]*pow(gamma, 3)/pow(drho_x[0], 7) - 103.0/8.0*pow(dq_x[0], 7)*drho_x[5]*pow(gamma, 2)/pow(drho_x[0], 7) + (5.0/8.0)*pow(dq_x[0], 7)*drho_x[5]*gamma/pow(drho_x[0], 7) + (15.0/2.0)*pow(dq_x[0], 7)*drho_x[5]/pow(drho_x[0], 7) + (43.0/8.0)*pow(dq_x[0], 7)*drho_x[1]*drho_x[4]*pow(gamma, 5)/pow(drho_x[0], 8) - 75.0/2.0*pow(dq_x[0], 7)*drho_x[1]*drho_x[4]*pow(gamma, 4)/pow(drho_x[0], 8) - 213.0/2.0*pow(dq_x[0], 7)*drho_x[1]*drho_x[4]*pow(gamma, 3)/pow(drho_x[0], 8) + (1451.0/4.0)*pow(dq_x[0], 7)*drho_x[1]*drho_x[4]*pow(gamma, 2)/pow(drho_x[0], 8) + (457.0/8.0)*pow(dq_x[0], 7)*drho_x[1]*drho_x[4]*gamma/pow(drho_x[0], 8) - 1125.0/4.0*pow(dq_x[0], 7)*drho_x[1]*drho_x[4]/pow(drho_x[0], 8) + (85.0/8.0)*pow(dq_x[0], 7)*drho_x[2]*drho_x[3]*pow(gamma, 5)/pow(drho_x[0], 8) - 645.0/8.0*pow(dq_x[0], 7)*drho_x[2]*drho_x[3]*pow(gamma, 4)/pow(drho_x[0], 8) - 1335.0/8.0*pow(dq_x[0], 7)*drho_x[2]*drho_x[3]*pow(gamma, 3)/pow(drho_x[0], 8) + (4975.0/8.0)*pow(dq_x[0], 7)*drho_x[2]*drho_x[3]*pow(gamma, 2)/pow(drho_x[0], 8) + (785.0/4.0)*pow(dq_x[0], 7)*drho_x[2]*drho_x[3]*gamma/pow(drho_x[0], 8) - 2325.0/4.0*pow(dq_x[0], 7)*drho_x[2]*drho_x[3]/pow(drho_x[0], 8) - 453.0/8.0*pow(dq_x[0], 7)*pow(drho_x[1], 2)*drho_x[3]*pow(gamma, 5)/pow(drho_x[0], 9) + (4173.0/8.0)*pow(dq_x[0], 7)*pow(drho_x[1], 2)*drho_x[3]*pow(gamma, 4)/pow(drho_x[0], 9) + (10683.0/8.0)*pow(dq_x[0], 7)*pow(drho_x[1], 2)*drho_x[3]*pow(gamma, 3)/pow(drho_x[0], 9) - 36623.0/8.0*pow(dq_x[0], 7)*pow(drho_x[1], 2)*drho_x[3]*pow(gamma, 2)/pow(drho_x[0], 9) - 7835.0/4.0*pow(dq_x[0], 7)*pow(drho_x[1], 2)*drho_x[3]*gamma/pow(drho_x[0], 9) + (18945.0/4.0)*pow(dq_x[0], 7)*pow(drho_x[1], 2)*drho_x[3]/pow(drho_x[0], 9) - 333.0/4.0*pow(dq_x[0], 7)*drho_x[1]*pow(drho_x[2], 2)*pow(gamma, 5)/pow(drho_x[0], 9) + (3233.0/4.0)*pow(dq_x[0], 7)*drho_x[1]*pow(drho_x[2], 2)*pow(gamma, 4)/pow(drho_x[0], 9) + (6863.0/4.0)*pow(dq_x[0], 7)*drho_x[1]*pow(drho_x[2], 2)*pow(gamma, 3)/pow(drho_x[0], 9) - 24763.0/4.0*pow(dq_x[0], 7)*drho_x[1]*pow(drho_x[2], 2)*pow(gamma, 2)/pow(drho_x[0], 9) - 6945.0/2.0*pow(dq_x[0], 7)*drho_x[1]*pow(drho_x[2], 2)*gamma/pow(drho_x[0], 9) + (14445.0/2.0)*pow(dq_x[0], 7)*drho_x[1]*pow(drho_x[2], 2)/pow(drho_x[0], 9) + (2749.0/8.0)*pow(dq_x[0], 7)*pow(drho_x[1], 3)*drho_x[2]*pow(gamma, 5)/pow(drho_x[0], 10) - 33685.0/8.0*pow(dq_x[0], 7)*pow(drho_x[1], 3)*drho_x[2]*pow(gamma, 4)/pow(drho_x[0], 10) - 76411.0/8.0*pow(dq_x[0], 7)*pow(drho_x[1], 3)*drho_x[2]*pow(gamma, 3)/pow(drho_x[0], 10) + (264655.0/8.0)*pow(dq_x[0], 7)*pow(drho_x[1], 3)*drho_x[2]*pow(gamma, 2)/pow(drho_x[0], 10) + (97791.0/4.0)*pow(dq_x[0], 7)*pow(drho_x[1], 3)*drho_x[2]*gamma/pow(drho_x[0], 10) - 176445.0/4.0*pow(dq_x[0], 7)*pow(drho_x[1], 3)*drho_x[2]/pow(drho_x[0], 10) - 475.0/2.0*pow(dq_x[0], 7)*pow(drho_x[1], 5)*pow(gamma, 5)/pow(drho_x[0], 11) + (7615.0/2.0)*pow(dq_x[0], 7)*pow(drho_x[1], 5)*pow(gamma, 4)/pow(drho_x[0], 11) + 8435*pow(dq_x[0], 7)*pow(drho_x[1], 5)*pow(gamma, 3)/pow(drho_x[0], 11) - 28775*pow(dq_x[0], 7)*pow(drho_x[1], 5)*pow(gamma, 2)/pow(drho_x[0], 11) - 56235.0/2.0*pow(dq_x[0], 7)*pow(drho_x[1], 5)*gamma/pow(drho_x[0], 11) + (89775.0/2.0)*pow(dq_x[0], 7)*pow(drho_x[1], 5)/pow(drho_x[0], 11) - 11.0/2.0*pow(dq_x[0], 6)*dq_x[1]*drho_x[4]*pow(gamma, 5)/pow(drho_x[0], 7) + (243.0/8.0)*pow(dq_x[0], 6)*dq_x[1]*drho_x[4]*pow(gamma, 4)/pow(drho_x[0], 7) + (1099.0/8.0)*pow(dq_x[0], 6)*dq_x[1]*drho_x[4]*pow(gamma, 3)/pow(drho_x[0], 7) - 2931.0/8.0*pow(dq_x[0], 6)*dq_x[1]*drho_x[4]*pow(gamma, 2)/pow(drho_x[0], 7) - 947.0/8.0*pow(dq_x[0], 6)*dq_x[1]*drho_x[4]*gamma/pow(drho_x[0], 7) + (645.0/2.0)*pow(dq_x[0], 6)*dq_x[1]*drho_x[4]/pow(drho_x[0], 7) + (817.0/8.0)*pow(dq_x[0], 6)*dq_x[1]*drho_x[1]*drho_x[3]*pow(gamma, 5)/pow(drho_x[0], 8) - 6171.0/8.0*pow(dq_x[0], 6)*dq_x[1]*drho_x[1]*drho_x[3]*pow(gamma, 4)/pow(drho_x[0], 8) - 23539.0/8.0*pow( ...
